# %% [markdown]
# <a href="https://colab.research.google.com/github/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/Modulo_para_la_graficaci%C3%B3n_de_vectores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="logo.fua" height="100px" src="https://www.uamerica.edu.co/wp-content/images/escudo.png" align="left" hspace="10px" vspace="0px"></p>
#
# <p><img alt="logo.fua" height="26px" src="https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-nd.svg" align="right" hspace="0px" vspace="11px"></p>
#
#
# # <center> <font size="6"> &nbsp;  &nbsp; &nbsp;  &nbsp; &nbsp;  &nbsp; &nbsp;  &nbsp; &nbsp;  &nbsp;**ÁLGEBRA LINEAL CON PYTHON &nbsp; &nbsp;&nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;     &nbsp; &nbsp;  &nbsp; MÓDULO PARA LA GRAFICACIÓN DE VECTORES** &nbsp;  &nbsp; &nbsp;  &nbsp; &nbsp;  &nbsp; &nbsp;  &nbsp; <center> &nbsp; &nbsp; &nbsp; &nbsp;*Jhonny Osorio Gallego* &nbsp; &nbsp; &nbsp;<p></font>

# %% [markdown]
# El siguiente módulo esta diseñado haciendo uso de la librería **NumPy** y **Plotly**, pretende servir de apoyo para la representación gráfica de vectores en el plano y el espacio, como estratégia para la enseñanza de los concéptos vectoriales.

# %% [markdown]
# ## **FUNCIÓN PARA GENERAR COLORES RGB ALEATORIAMENTE**

# %%
import random 
def randomRgbaColor(): 
   r = random.randrange(0, 255) 
   g = random.randrange(0, 255)  
   b =random.randrange(0, 255)
   return "rgb"+ "(" + str(r) + "," + str(g) + ","+ str(b) + ")"

# %% [markdown]
# ## **DEFINICIÓN UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES FIJOS EN EL PLANO**
#
# La función tiene como sintaxis **plotvectorsf2D** permite graficar multiples vectores en el plano cartesiano.

# %%
import plotly.graph_objects as go
import numpy as np


def plotvectorsf2D(*args):

    '''Función elaborada con el módulo Plotly y NumPy  para representar multiples vectores fijos en el plano'''
    
    fig = go.Figure()
    x = [0]
    y = [0]
    for V in args:
        color = randomRgbaColor()
        x.append(V[0])
        y.append(V[1])
        #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
        fig.add_trace(go.Scatter(x=[0,V[0]], y=[0,V[1]],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(V)+1)))
        fig.add_annotation(
        x=V[0],  # Coordenada en x cabeza
        y=V[1],  # Coordenada en y cabeza
        ax=0.0,  # Coordenada en x de la cola
        ay=0.0,  # Coordenada en x de la cola
        xref='x',
        yref='y',
        axref='x',
        ayref='y',
        showarrow=True,
        arrowhead=2,
        arrowsize=1.5,
        arrowwidth=2.3,
        arrowcolor = color)
        
    fig.add_trace(go.Scatter(x=[0],y=[0],mode='markers',marker=dict(color="#2a3f5f",size=9),showlegend=True,opacity=1,name="origen"))

    fig.add_annotation(ax = min(x)-0.54, axref = 'x', ay = 0, ayref = 'y',x = max(x)+0.5, xref = 'x', y = 0, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(ax = 0, axref = 'x', ay = min(y)-0.54, ayref = 'y',x = 0, xref = 'x', y = max(y)+0.5, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(text="$x$", x=max(x)+0.5, y=-0.2, arrowhead=1, showarrow=False)
    fig.add_annotation(text="$y$", x=-0.2, y=max(y)+0.5, arrowhead=1, showarrow=False)

    fig.update_xaxes(title = "$\large{x}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(x)-0.5, max(x)+0.5],showgrid = True) #,zerolinecolor="black" ,autorange = True
    fig.update_yaxes(title = "$\large{y}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(y)-0.5, max(y)+0.5],showgrid = True) #, zerolinecolor= "black" ,autorange = True
    fig.update_layout(font=dict(family="latex",size=20,color="black")) #y=1.2,x=0.03
    #fig.update_layout(title= "",title_font=dict(size=5, family='latex', color='rgb(1,21,51)'),title_x=0.5)
    fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="right",x=1, itemdoubleclick ="toggle"),title_font=dict(size=30, color='rgb(1,21,51)'),showlegend=True,width=500, height=480)
    fig.show()

# %%
plotvectorsf2D([3,20],[-10,20],[50,30],[-10,-40],[20,-40])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a63af5d7-4787-4a09-9a5f-9bdf818aeb57" class="plotly-graph-div" style="height:480px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a63af5d7-4787-4a09-9a5f-9bdf818aeb57")) {
#                     Plotly.newPlot(
#                         'a63af5d7-4787-4a09-9a5f-9bdf818aeb57',
#                         [{"marker": {"color": "rgb(236,215,100)", "size": 8}, "mode": "lines", "name": "vector 1", "showlegend": true, "type": "scatter", "x": [0, 3], "y": [0, 20]}, {"marker": {"color": "rgb(128,117,25)", "size": 8}, "mode": "lines", "name": "vector 2", "showlegend": true, "type": "scatter", "x": [0, -10], "y": [0, 20]}, {"marker": {"color": "rgb(118,118,5)", "size": 8}, "mode": "lines", "name": "vector 3", "showlegend": true, "type": "scatter", "x": [0, 50], "y": [0, 30]}, {"marker": {"color": "rgb(2,162,190)", "size": 8}, "mode": "lines", "name": "vector 4", "showlegend": true, "type": "scatter", "x": [0, -10], "y": [0, -40]}, {"marker": {"color": "rgb(120,64,124)", "size": 8}, "mode": "lines", "name": "vector 5", "showlegend": true, "type": "scatter", "x": [0, 20], "y": [0, -40]}, {"marker": {"color": "#2a3f5f", "size": 9}, "mode": "markers", "name": "origen", "opacity": 1, "showlegend": true, "type": "scatter", "x": [0], "y": [0]}],
#                         {"annotations": [{"arrowcolor": "rgb(236,215,100)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 3, "xref": "x", "y": 20, "yref": "y"}, {"arrowcolor": "rgb(128,117,25)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": -10, "xref": "x", "y": 20, "yref": "y"}, {"arrowcolor": "rgb(118,118,5)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 50, "xref": "x", "y": 30, "yref": "y"}, {"arrowcolor": "rgb(2,162,190)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": -10, "xref": "x", "y": -40, "yref": "y"}, {"arrowcolor": "rgb(120,64,124)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 20, "xref": "x", "y": -40, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": -10.54, "axref": "x", "ay": 0, "ayref": "y", "x": 50.5, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": 0, "axref": "x", "ay": -40.54, "ayref": "y", "x": 0, "xref": "x", "y": 30.5, "yref": "y"}, {"arrowhead": 1, "showarrow": false, "text": "$x$", "x": 50.5, "y": -0.2}, {"arrowhead": 1, "showarrow": false, "text": "$y$", "x": -0.2, "y": 30.5}], "font": {"color": "black", "family": "latex", "size": 20}, "height": 480, "legend": {"itemdoubleclick": "toggle", "orientation": "h", "x": 1, "xanchor": "right", "y": 1.02, "yanchor": "bottom"}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555 ...

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES FIJOS EN EL ESPACIO**
# La función tiene como sintaxis **plotvectorsf3D** permite graficar multiples vectores en el plano cartesiano.

# %%
import plotly.graph_objs as go
from plotly.offline import plot
import numpy as np


def plotvectorsf3D(*args):

    ''''Función elaborada con el módulo Plotly y NumPy para representar gráficamente multiples vectores fijos en el espacio'''
    data = []
    x = [0]
    y = [0]
    z = [0.3,-0.3]
    
    for V in args:
        x.append(V[0])
        y.append(V[1])
        z.append(V[2])
    
    escala =(max(x)+max(y)+max(z))/15
    
    
    
    for V in args:
        x.append(V[0])
        y.append(V[1])
        z.append(V[2])
        color = randomRgbaColor()
        vector = go.Scatter3d( 
        x = [0,V[0]],
        y = [0,V[1]],
        z = [0,V[2]],
        marker = dict( size = 1,color= color),
        line = dict( color= color, width = 7),name="vector "+ str(args.index(V)+1))
        
        paleta = [[0, color],[1, color]]

        cono = go.Cone(x=[V[0]], y=[V[1]], z=[V[2]], u=[V[0]], v=[V[1]], w=[V[2]],sizemode="absolute",sizeref= escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(V)+1))
        
        data += [vector,cono]
        layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

    paleta2 = [[0, "#2a3f5f"],[1, "#2a3f5f"]]
    point = go.Scatter3d( x = [0],y = [0],z = [0], mode='markers',marker=dict(color= "#2a3f5f",size=5),showlegend=True,name="origen")
    
    axex = go.Scatter3d( 
        x = [min(x)-escala, max(x)+escala],
        y = [0,0],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    
    conox = go.Cone(x=[max(x)+ escala], y=[0], z=[0], u=[max(x)+escala], v=[0], w=[0],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),name="Eje x-positivo")
    
    axey = go.Scatter3d( 
        x = [0,0],
        y = [min(y)-escala,max(y)+escala],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color="#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    conoy = go.Cone(x=[0], y=[max(y)+escala], z=[0], u=[0], v=[max(y)+escala], w=[0],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje y-positivo ")
    
    axez = go.Scatter3d( 
        x = [0,0],
        y = [0,0],
        z = [min(z)-escala,max(z)+escala],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="eje z-positivo")
    
    conoz = go.Cone(x=[0], y=[0], z=[max(z)+escala], u=[0], v=[0], w=[max(z)+escala],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo= "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje z-positivo")
    
    
    #plano = go.Surface(x = np.linspace(min(x),max(x),500), y = np.linspace(min(y),max(y),500) ,z = np.zeros(500),showscale=False)

    fig = go.Figure(data= data + [point, axex, conox, axey, conoy, axez, conoz] ,layout=layout)


    fig.update_layout(legend=dict(orientation="h",y=1.3,x=0.03),title_font=dict(size=50, color='rgb(1,21,51)'),showlegend=True,width=480, height=480)


    plot(fig,image_height=800,image_width=800)
    fig.show()

# %%
plotvectorsf3D([1,2,-3],[2,-3,1],[-2,-4,5])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4e73d677-3841-49a0-bcd3-2e39b2c129a4" class="plotly-graph-div" style="height:480px; width:480px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e73d677-3841-49a0-bcd3-2e39b2c129a4")) {
#                     Plotly.newPlot(
#                         '4e73d677-3841-49a0-bcd3-2e39b2c129a4',
#                         [{"line": {"color": "rgb(29,148,218)", "width": 7}, "marker": {"color": "rgb(29,148,218)", "size": 1}, "name": "vector 1", "type": "scatter3d", "x": [0, 1], "y": [0, 2], "z": [0, -3]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(29,148,218)"], [1, "rgb(29,148,218)"]], "name": "vector 1", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [1], "v": [2], "w": [-3], "x": [1], "y": [2], "z": [-3]}, {"line": {"color": "rgb(239,6,171)", "width": 7}, "marker": {"color": "rgb(239,6,171)", "size": 1}, "name": "vector 2", "type": "scatter3d", "x": [0, 2], "y": [0, -3], "z": [0, 1]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(239,6,171)"], [1, "rgb(239,6,171)"]], "name": "vector 2", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [2], "v": [-3], "w": [1], "x": [2], "y": [-3], "z": [1]}, {"line": {"color": "rgb(158,231,7)", "width": 7}, "marker": {"color": "rgb(158,231,7)", "size": 1}, "name": "vector 3", "type": "scatter3d", "x": [0, -2], "y": [0, -4], "z": [0, 5]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(158,231,7)"], [1, "rgb(158,231,7)"]], "name": "vector 3", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [-2], "v": [-4], "w": [5], "x": [-2], "y": [-4], "z": [5]}, {"marker": {"color": "#2a3f5f", "size": 5}, "mode": "markers", "name": "origen", "showlegend": true, "type": "scatter3d", "x": [0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [-2.6, 2.6], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje x-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.36, "type": "cone", "u": [2.6], "v": [0], "w": [0], "x": [2.6], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [-4.6, 2.6], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje y-positivo ", "showscale": false, "sizemode": "absolute", "sizeref": 0.36, "type": "cone", "u": [0], "v": [2.6], "w": [0], "x": [0], "y": [2.6], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "eje z-positivo", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [0, 0], "z": [-3.6, 5.6]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje z-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.36, "type": "cone", "u": [0], "v": [0], "w": [5.6], "x": [0], "y": [0], "z": [5.6]}],
#                         {"height": 480, "legend": {"orientation": "h", "x": 0.03, "y": 1.3}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "typ

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES EN EL PLANO**
# La función tiene como sintaxis **plotvectorsl2D** permite graficar multiples vectores libres en el plano cartesiano.

# %%
import plotly.graph_objects as go
import numpy as np


def plotvectorsl2D(*args):
    '''Función elaborada en el módulo Plotly y NumPy para reprsentar graficamente multiples vectores libres en el plano'''
    
    fig = go.Figure()
    x = [0] 
    y = [0]
    for V in args:
        color = randomRgbaColor()
        x.append(V[0][0])
        x.append(V[1][0])
        y.append(V[0][1])
        y.append(V[1][1])
        #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
        fig.add_trace(go.Scatter(x=[V[0][0],V[1][0]], y=[V[0][1],V[1][1]],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(V)+1)))
        fig.add_annotation(
        x=V[1][0],  # Coordenada en x cabeza
        y=V[1][1],  # Coordenada en y cabeza
        ax=V[0][0],  # Coordenada en x de la cola
        ay=V[0][1],  # Coordenada en y de la cola
        xref='x',
        yref='y',
        axref='x',
        ayref='y',
        showarrow=True,
        arrowhead=2,
        arrowsize=1.5,
        arrowwidth=2.3,
        arrowcolor = color)
        
    fig.add_trace(go.Scatter(x=[0],y=[0],mode='markers',marker=dict(color="#2a3f5f",size=9),showlegend=True,opacity=1,name="origen"))

    fig.add_annotation(ax = min(x)-0.5, axref = 'x', ay = 0, ayref = 'y',x = max(x)+0.5, xref = 'x', y = 0, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(ax = 0, axref = 'x', ay = min(y)-0.5, ayref = 'y',x = 0, xref = 'x', y = max(y)+0.5, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(text="$x$", x=max(x)+0.5, y=-0.2, arrowhead=1, showarrow=False)
    fig.add_annotation(text="$y$", x=-0.2, y=max(y)+0.5, arrowhead=1, showarrow=False)

    fig.update_xaxes(title = "$\large{x}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(x)-0.5, max(x)+0.5],showgrid = True) #,zerolinecolor="black" ,autorange = True
    fig.update_yaxes(title = "$\large{y}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(y)-0.4, max(y)+0.5],showgrid = True) #, zerolinecolor= "black" ,autorange = True
    fig.update_layout(font=dict(family="latex",size=20,color="black")) #y=1.2,x=0.03
    #fig.update_layout(title= "",title_font=dict(size=5, family='latex', color='rgb(1,21,51)'),title_x=0.5)
    fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="right",x=1, itemdoubleclick ="toggle"),title_font=dict(size=30, color='rgb(1,21,51)'),showlegend=True,width=500, height=480)
    fig.show()

# %%
plotvectorsl2D([(1,2),(3,4)],[(3,4),(2,2)],[(2,2),(0,0)],[(0,0),(1,2)])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="27724a54-5dcd-4849-8097-406a2b71ee90" class="plotly-graph-div" style="height:480px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27724a54-5dcd-4849-8097-406a2b71ee90")) {
#                     Plotly.newPlot(
#                         '27724a54-5dcd-4849-8097-406a2b71ee90',
#                         [{"marker": {"color": "rgb(50,133,106)", "size": 8}, "mode": "lines", "name": "vector 1", "showlegend": true, "type": "scatter", "x": [1, 3], "y": [2, 4]}, {"marker": {"color": "rgb(136,23,163)", "size": 8}, "mode": "lines", "name": "vector 2", "showlegend": true, "type": "scatter", "x": [3, 2], "y": [4, 2]}, {"marker": {"color": "rgb(81,142,218)", "size": 8}, "mode": "lines", "name": "vector 3", "showlegend": true, "type": "scatter", "x": [2, 0], "y": [2, 0]}, {"marker": {"color": "rgb(72,170,42)", "size": 8}, "mode": "lines", "name": "vector 4", "showlegend": true, "type": "scatter", "x": [0, 1], "y": [0, 2]}, {"marker": {"color": "#2a3f5f", "size": 9}, "mode": "markers", "name": "origen", "opacity": 1, "showlegend": true, "type": "scatter", "x": [0], "y": [0]}],
#                         {"annotations": [{"arrowcolor": "rgb(50,133,106)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 1, "axref": "x", "ay": 2, "ayref": "y", "showarrow": true, "x": 3, "xref": "x", "y": 4, "yref": "y"}, {"arrowcolor": "rgb(136,23,163)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 3, "axref": "x", "ay": 4, "ayref": "y", "showarrow": true, "x": 2, "xref": "x", "y": 2, "yref": "y"}, {"arrowcolor": "rgb(81,142,218)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 2, "axref": "x", "ay": 2, "ayref": "y", "showarrow": true, "x": 0, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "rgb(72,170,42)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0, "axref": "x", "ay": 0, "ayref": "y", "showarrow": true, "x": 1, "xref": "x", "y": 2, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": -0.5, "axref": "x", "ay": 0, "ayref": "y", "x": 3.5, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": 0, "axref": "x", "ay": -0.5, "ayref": "y", "x": 0, "xref": "x", "y": 4.5, "yref": "y"}, {"arrowhead": 1, "showarrow": false, "text": "$x$", "x": 3.5, "y": -0.2}, {"arrowhead": 1, "showarrow": false, "text": "$y$", "x": -0.2, "y": 4.5}], "font": {"color": "black", "family": "latex", "size": 20}, "height": 480, "legend": {"itemdoubleclick": "toggle", "orientation": "h", "x": 1, "xanchor": "right", "y": 1.02, "yanchor": "bottom"}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": " ...

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES O FIJOS EN EL PLANO**
# La función tiene como sintaxis **plotvectors2D** permite graficar multiples vectores libres en el plano cartesiano.

# %%
def plotvectors2D(*args):
    '''Función elaborada con el módulo Plotly y Numpy para representar multiples vectores fijos y libres en el plano'''
    fig = go.Figure()
    x = [0]
    y = [0]
    for V in args:
        if type(V[0]) == int or type(V[0]) == float :
            color = randomRgbaColor()
            x.append(V[0])
            y.append(V[1])
            #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
            fig.add_trace(go.Scatter(x=[0,V[0]], y=[0,V[1]],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(V)+1)))
            fig.add_annotation(
            x=V[0],  # Coordenada en x cabeza
            y=V[1],  # Coordenada en y cabeza
            ax=0.0,  # Coordenada en x de la cola
            ay=0.0,  # Coordenada en x de la cola
            xref='x',
            yref='y',
            axref='x',
            ayref='y',
            showarrow=True,
            arrowhead=2,
            arrowsize=1.5,
            arrowwidth=2.3,
            arrowcolor = color)
        else:
            color = randomRgbaColor()
            x.append(V[0][0])
            x.append(V[1][0])
            y.append(V[0][1])
            y.append(V[1][1])
            #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
            fig.add_trace(go.Scatter(x=[V[0][0],V[1][0]], y=[V[0][1],V[1][1]],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(V)+1)))
            fig.add_annotation(
            x=V[1][0],  # Coordenada en x cabeza
            y=V[1][1],  # Coordenada en y cabeza
            ax=V[0][0],  # Coordenada en x de la cola
            ay=V[0][1],  # Coordenada en y de la cola
            xref='x',
            yref='y',
            axref='x',
            ayref='y',
            showarrow=True,
            arrowhead=2,
            arrowsize=1.5,
            arrowwidth=2.3,
            arrowcolor = color)

    fig.add_trace(go.Scatter(x=[0],y=[0],mode='markers',marker=dict(color="#2a3f5f",size=9),showlegend=True,opacity=1,name="origen"))

    fig.add_annotation(ax = min(x)-0.54, axref = 'x', ay = 0, ayref = 'y',x = max(x)+0.5, xref = 'x', y = 0, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(ax = 0, axref = 'x', ay = min(y)-0.54, ayref = 'y',x = 0, xref = 'x', y = max(y)+0.5, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(text="$x$", x=max(x)+0.5, y=-0.2, arrowhead=1, showarrow=False)
    fig.add_annotation(text="$y$", x=-0.2, y=max(y)+0.5, arrowhead=1, showarrow=False)

    fig.update_xaxes(title = "$\large{x}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(x)-0.5, max(x)+0.5],showgrid = True) #,zerolinecolor="black" ,autorange = True
    fig.update_yaxes(title = "$\large{y}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(y)-0.4, max(y)+0.5],showgrid = True) #, zerolinecolor= "black" ,autorange = True
    fig.update_layout(font=dict(family="latex",size=20,color="black")) #y=1.2,x=0.03
    #fig.update_layout(title= "",title_font=dict(size=5, family='latex', color='rgb(1,21,51)'),title_x=0.5)
    fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="right",x=1, itemdoubleclick ="toggle"),title_font=dict(size=30, color='rgb(1,21,51)'),showlegend=True,width=500, height=480)
    fig.show()

# %%
plotvectors2D([1,2],[(1,2),(4,3)],[4,3],[3,1])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dae30cea-8586-4a69-830b-936058fadd4c" class="plotly-graph-div" style="height:480px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dae30cea-8586-4a69-830b-936058fadd4c")) {
#                     Plotly.newPlot(
#                         'dae30cea-8586-4a69-830b-936058fadd4c',
#                         [{"marker": {"color": "rgb(39,66,190)", "size": 8}, "mode": "lines", "name": "vector 1", "showlegend": true, "type": "scatter", "x": [0, 1], "y": [0, 2]}, {"marker": {"color": "rgb(64,217,133)", "size": 8}, "mode": "lines", "name": "vector 2", "showlegend": true, "type": "scatter", "x": [1, 4], "y": [2, 3]}, {"marker": {"color": "rgb(98,2,170)", "size": 8}, "mode": "lines", "name": "vector 3", "showlegend": true, "type": "scatter", "x": [0, 4], "y": [0, 3]}, {"marker": {"color": "rgb(162,8,227)", "size": 8}, "mode": "lines", "name": "vector 4", "showlegend": true, "type": "scatter", "x": [0, 3], "y": [0, 1]}, {"marker": {"color": "#2a3f5f", "size": 9}, "mode": "markers", "name": "origen", "opacity": 1, "showlegend": true, "type": "scatter", "x": [0], "y": [0]}],
#                         {"annotations": [{"arrowcolor": "rgb(39,66,190)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 1, "xref": "x", "y": 2, "yref": "y"}, {"arrowcolor": "rgb(64,217,133)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 1, "axref": "x", "ay": 2, "ayref": "y", "showarrow": true, "x": 4, "xref": "x", "y": 3, "yref": "y"}, {"arrowcolor": "rgb(98,2,170)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 4, "xref": "x", "y": 3, "yref": "y"}, {"arrowcolor": "rgb(162,8,227)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 3, "xref": "x", "y": 1, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": -0.54, "axref": "x", "ay": 0, "ayref": "y", "x": 4.5, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": 0, "axref": "x", "ay": -0.54, "ayref": "y", "x": 0, "xref": "x", "y": 3.5, "yref": "y"}, {"arrowhead": 1, "showarrow": false, "text": "$x$", "x": 4.5, "y": -0.2}, {"arrowhead": 1, "showarrow": false, "text": "$y$", "x": -0.2, "y": 3.5}], "font": {"color": "black", "family": "latex", "size": 20}, "height": 480, "legend": {"itemdoubleclick": "toggle", "orientation": "h", "x": 1, "xanchor": "right", "y": 1.02, "yanchor": "bottom"}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, ...

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES EN EL ESPACIO**
# La función tiene como sintaxis **plotvectorsl3D** permite graficar multiples vectores en el espacio.

# %%
import plotly.graph_objs as go
from plotly.offline import plot
import numpy as np


def plotvectorsl3D(*args):
    '''Función elaborada en el módulo Plotly y NumPy para representar graficamente multiples vectores libres en el espacio'''
    data = []
    x = [0]
    y = [0]
    z = [0.3,-0.3]


    for V in args:
        x.append(V[0][0])
        x.append(V[1][0])

        y.append(V[0][1])
        y.append(V[1][1])

        z.append(V[0][2])
        z.append(V[1][2])
    

    escala =(max(x)+max(y)+max(z))/30
    
    
    
    for V in args:
        x.append(V[0][0])
        x.append(V[1][0])

        y.append(V[0][1])
        y.append(V[1][1])

        z.append(V[0][2])
        z.append(V[1][2])

        nombre = "Tail"+ "=" + "(" + str(V[0][0])  + "," + str(V[0][1]) +"," +str(V[0][2]) + ")" + "\n" + "Head"+ "=" + "(" + str(V[1][0])  + "," + str(V[1][1]) +"," +str(V[1][2]) + ")"

        color = randomRgbaColor()
        vector = go.Scatter3d( 
        x = [V[0][0],V[1][0]],
        y = [V[0][1],V[1][1]],
        z = [V[0][2],V[1][2]],
        hoverinfo = "name + text",
        hovertext = nombre,
        marker = dict( size = 1,color= color),
        line = dict( color= color, width = 7),name="vector "+ str(args.index(V)+1))
        
        paleta = [[0, color],[1, color]]

        cono = go.Cone(x=[V[1][0]-0.063*(V[1][0]-V[0][0])], y=[V[1][1]-0.063*(V[1][1]-V[0][1])], z=[V[1][2]-0.063*(V[1][2]-V[0][2])], u=[0.5*(V[1][0]-V[0][0])], v=[0.5*(V[1][1]-V[0][1])], w=[0.5*(V[1][2]-V[0][2])],sizemode="absolute",sizeref=escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               hoverinfo = "skip",
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(V)+1))
        
        data += [vector,cono]
        layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

    paleta2 = [[0, "#2a3f5f"],[1, "#2a3f5f"]]
    point = go.Scatter3d( x = [0],y = [0],z = [0], mode='markers',marker=dict(color= "#2a3f5f",size=5),showlegend=True,name="origen")
    
    axex = go.Scatter3d( 
        x = [min(x)-escala, max(x)+ escala],
        y = [0,0],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    
    conox = go.Cone(x=[max(x) + escala], y=[0], z=[0], u=[max(x)+ escala], v=[0], w=[0],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),name="Eje x-positivo")
    
    axey = go.Scatter3d( 
        x = [0,0],
        y = [min(y)-escala,max(y)+escala],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color="#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    conoy = go.Cone(x=[0], y=[max(y)+ escala], z=[0], u=[0], v=[max(y)+escala], w=[0],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje y-positivo ")
    
    axez = go.Scatter3d( 
        x = [0,0],
        y = [0,0],
        z = [min(z)-escala,max(z)+escala],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="eje z-positivo")
    
    conoz = go.Cone(x=[0], y=[0], z=[max(z)+escala], u=[0], v=[0], w=[max(z)+escala],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo= "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje z-positivo")
    
    
    #plano = go.Surface(x = np.linspace(min(x),max(x),500), y = np.linspace(min(y),max(y),500) ,z = np.zeros(500),showscale=False)

    fig = go.Figure(data= data + [point, axex, conox, axey, conoy, axez, conoz] ,layout=layout)


    fig.update_layout(legend=dict(orientation="h",y=1.3,x=0.03),title_font=dict(size=50, color='rgb(1,21,51)'),showlegend=True,width=480, height=480)


    plot(fig,image_height=800,image_width=800)
    fig.show()

# %%
plotvectorsl3D([(1,2,3),(4,5,6)],[(1,2,3),(4,3,6)],[(4,5,6),(4,3,6)])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d2390f9e-3a16-42ec-9f8b-c5bf5e6d762c" class="plotly-graph-div" style="height:480px; width:480px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d2390f9e-3a16-42ec-9f8b-c5bf5e6d762c")) {
#                     Plotly.newPlot(
#                         'd2390f9e-3a16-42ec-9f8b-c5bf5e6d762c',
#                         [{"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(4,5,6)", "line": {"color": "rgb(203,149,185)", "width": 7}, "marker": {"color": "rgb(203,149,185)", "size": 1}, "name": "vector 1", "type": "scatter3d", "x": [1, 4], "y": [2, 5], "z": [3, 6]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(203,149,185)"], [1, "rgb(203,149,185)"]], "hoverinfo": "skip", "name": "vector 1", "showscale": false, "sizemode": "absolute", "sizeref": 0.5, "type": "cone", "u": [1.5], "v": [1.5], "w": [1.5], "x": [3.811], "y": [4.811], "z": [5.811]}, {"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(4,3,6)", "line": {"color": "rgb(209,147,81)", "width": 7}, "marker": {"color": "rgb(209,147,81)", "size": 1}, "name": "vector 2", "type": "scatter3d", "x": [1, 4], "y": [2, 3], "z": [3, 6]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(209,147,81)"], [1, "rgb(209,147,81)"]], "hoverinfo": "skip", "name": "vector 2", "showscale": false, "sizemode": "absolute", "sizeref": 0.5, "type": "cone", "u": [1.5], "v": [0.5], "w": [1.5], "x": [3.811], "y": [2.937], "z": [5.811]}, {"hoverinfo": "name+text", "hovertext": "Tail=(4,5,6)\nHead=(4,3,6)", "line": {"color": "rgb(193,78,248)", "width": 7}, "marker": {"color": "rgb(193,78,248)", "size": 1}, "name": "vector 3", "type": "scatter3d", "x": [4, 4], "y": [5, 3], "z": [6, 6]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(193,78,248)"], [1, "rgb(193,78,248)"]], "hoverinfo": "skip", "name": "vector 3", "showscale": false, "sizemode": "absolute", "sizeref": 0.5, "type": "cone", "u": [0.0], "v": [-1.0], "w": [0.0], "x": [4.0], "y": [3.126], "z": [6.0]}, {"marker": {"color": "#2a3f5f", "size": 5}, "mode": "markers", "name": "origen", "showlegend": true, "type": "scatter3d", "x": [0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [-0.5, 4.5], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje x-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.3, "type": "cone", "u": [4.5], "v": [0], "w": [0], "x": [4.5], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [-0.5, 5.5], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje y-positivo ", "showscale": false, "sizemode": "absolute", "sizeref": 0.3, "type": "cone", "u": [0], "v": [5.5], "w": [0], "x": [0], "y": [5.5], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "eje z-positivo", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [0, 0], "z": [-0.8, 6.5]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje z-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.3, "type": "cone", "u": [0], "v": [0], "w": [6.5], "x": [0], "y": [0], "z": [6.5]}],
#                         {"height": 480, "legend": {"orientation": "h", "x": 0.03, "y": 1.3}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES Y FIJOS EN EL ESPACIO**
# La función tiene como sintaxis **plotvectors3D** permite graficar multiples vectores fijos y libres en el espacio.

# %%
import plotly.graph_objs as go
from plotly.offline import plot
import numpy as np


def plotvectors3D(*args):
    '''Función elaborada en el módulo Plotly y NumPy para representar graficamente multiples vectores libres y fijos en el espacio'''
    data = []
    x = [0]
    y = [0]
    z = [0.3,-0.3]


    for V in args:
        if type(V[0]) == int or type(V[0]) == float :
            x.append(V[0])
            y.append(V[1])
            z.append(V[2])

        else:

             x.append(V[0][0])
             x.append(V[1][0])

             y.append(V[0][1])
             y.append(V[1][1])

             z.append(V[0][2])
             z.append(V[1][2])
        
    escala = (max(x)+max(y)+max(z))/30

    
    for V in args:
        if type(V[0]) == int or type(V[0]) == float :
            x.append(V[0])
            y.append(V[1])
            z.append(V[2])
            color = randomRgbaColor()
            vector = go.Scatter3d( 
            x = [0,V[0]],
            y = [0,V[1]],
            z = [0,V[2]],
            marker = dict( size = 1,color= color),
            line = dict( color= color, width = 7),name="vector "+ str(args.index(V)+1))
        
            paleta = [[0, color],[1, color]]

            cono = go.Cone(x=[V[0]], y=[V[1]], z=[V[2]], u=[V[0]], v=[V[1]], w=[V[2]],sizemode="absolute",sizeref=escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(V)+1))
        
            data += [vector,cono]
            layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

        else:
             x.append(V[0][0])
             x.append(V[1][0])

             y.append(V[0][1])
             y.append(V[1][1])

             z.append(V[0][2])
             z.append(V[1][2])

             nombre = "Tail"+ "=" + "(" + str(V[0][0])  + "," + str(V[0][1]) +"," +str(V[0][2]) + ")" + "\n" + "Head"+ "=" + "(" + str(V[1][0])  + "," + str(V[1][1]) +"," +str(V[1][2]) + ")"

             color = randomRgbaColor()
             vector = go.Scatter3d( 
             x = [V[0][0],V[1][0]],
             y = [V[0][1],V[1][1]],
             z = [V[0][2],V[1][2]],
             hoverinfo = "name + text",
             hovertext = nombre,
             marker = dict( size = 1,color= color),
             line = dict( color= color, width = 7),name="vector "+ str(args.index(V)+1))
        
             paleta = [[0, color],[1, color]]

             cono = go.Cone(x=[V[1][0]-0.063*(V[1][0]-V[0][0])], y=[V[1][1]-0.063*(V[1][1]-V[0][1])], z=[V[1][2]-0.063*(V[1][2]-V[0][2])], u=[0.5*(V[1][0]-V[0][0])], v=[0.5*(V[1][1]-V[0][1])], w=[0.5*(V[1][2]-V[0][2])],sizemode="absolute",sizeref=escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               hoverinfo = "skip",
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(V)+1))
        
             data += [vector,cono]
             layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

    paleta2 = [[0, "#2a3f5f"],[1, "#2a3f5f"]]
    point = go.Scatter3d( x = [0],y = [0],z = [0], mode='markers',marker=dict(color= "#2a3f5f",size=5),showlegend=True,name="origen")
    
    axex = go.Scatter3d( 
        x = [min(x)-escala, max(x)+escala],
        y = [0,0],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    
    conox = go.Cone(x=[max(x)+escala], y=[0], z=[0], u=[max(x)+escala], v=[0], w=[0],sizemode="absolute",sizeref= escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),name="Eje x-positivo")
    
    axey = go.Scatter3d( 
        x = [0,0],
        y = [min(y)-escala,max(y)+escala],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color="#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    conoy = go.Cone(x=[0], y=[max(y)+escala], z=[0], u=[0], v=[max(y)+escala], w=[0],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje y-positivo ")
    
    axez = go.Scatter3d( 
        x = [0,0],
        y = [0,0],
        z = [min(z)-escala,max(z)+escala],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="eje z-positivo")
    
    conoz = go.Cone(x=[0], y=[0], z=[max(z)+escala], u=[0], v=[0], w=[max(z)+escala],sizemode="absolute",sizeref=escala*0.6,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo= "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje z-positivo")
    
    
    #plano = go.Surface(x = np.linspace(min(x),max(x),500), y = np.linspace(min(y),max(y),500) ,z = np.zeros(500),showscale=False)

    fig = go.Figure(data= data + [point, axex, conox, axey, conoy, axez, conoz] ,layout=layout)


    fig.update_layout(legend=dict(orientation="h",y=1.3,x=0.03),title_font=dict(size=50, color='rgb(1,21,51)'),showlegend=True,width=480, height=480)


    plot(fig,image_height=800,image_width=800)
    fig.show()

# %%
plotvectors3D([10,20,30],[(10,20,30),(50,40,60)],[50,40,60],[40,20,30])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e9aefff3-0d1c-4c71-aee0-3ddb7a12bda0" class="plotly-graph-div" style="height:480px; width:480px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9aefff3-0d1c-4c71-aee0-3ddb7a12bda0")) {
#                     Plotly.newPlot(
#                         'e9aefff3-0d1c-4c71-aee0-3ddb7a12bda0',
#                         [{"line": {"color": "rgb(162,69,76)", "width": 7}, "marker": {"color": "rgb(162,69,76)", "size": 1}, "name": "vector 1", "type": "scatter3d", "x": [0, 10], "y": [0, 20], "z": [0, 30]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(162,69,76)"], [1, "rgb(162,69,76)"]], "name": "vector 1", "showscale": false, "sizemode": "absolute", "sizeref": 5.0, "type": "cone", "u": [10], "v": [20], "w": [30], "x": [10], "y": [20], "z": [30]}, {"hoverinfo": "name+text", "hovertext": "Tail=(10,20,30)\nHead=(50,40,60)", "line": {"color": "rgb(188,87,230)", "width": 7}, "marker": {"color": "rgb(188,87,230)", "size": 1}, "name": "vector 2", "type": "scatter3d", "x": [10, 50], "y": [20, 40], "z": [30, 60]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(188,87,230)"], [1, "rgb(188,87,230)"]], "hoverinfo": "skip", "name": "vector 2", "showscale": false, "sizemode": "absolute", "sizeref": 5.0, "type": "cone", "u": [20.0], "v": [10.0], "w": [15.0], "x": [47.48], "y": [38.74], "z": [58.11]}, {"line": {"color": "rgb(82,210,254)", "width": 7}, "marker": {"color": "rgb(82,210,254)", "size": 1}, "name": "vector 3", "type": "scatter3d", "x": [0, 50], "y": [0, 40], "z": [0, 60]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(82,210,254)"], [1, "rgb(82,210,254)"]], "name": "vector 3", "showscale": false, "sizemode": "absolute", "sizeref": 5.0, "type": "cone", "u": [50], "v": [40], "w": [60], "x": [50], "y": [40], "z": [60]}, {"line": {"color": "rgb(217,82,148)", "width": 7}, "marker": {"color": "rgb(217,82,148)", "size": 1}, "name": "vector 4", "type": "scatter3d", "x": [0, 40], "y": [0, 20], "z": [0, 30]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(217,82,148)"], [1, "rgb(217,82,148)"]], "name": "vector 4", "showscale": false, "sizemode": "absolute", "sizeref": 5.0, "type": "cone", "u": [40], "v": [20], "w": [30], "x": [40], "y": [20], "z": [30]}, {"marker": {"color": "#2a3f5f", "size": 5}, "mode": "markers", "name": "origen", "showlegend": true, "type": "scatter3d", "x": [0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [-5.0, 55.0], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje x-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 3.0, "type": "cone", "u": [55.0], "v": [0], "w": [0], "x": [55.0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [-5.0, 45.0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje y-positivo ", "showscale": false, "sizemode": "absolute", "sizeref": 3.0, "type": "cone", "u": [0], "v": [45.0], "w": [0], "x": [0], "y": [45.0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "eje z-positivo", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [0, 0], "z": [-5.3, 65.0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje z-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 3.0, "type": "cone", "u": [0], "v": [0], "w": [65.0], "x": [0], "y": [0], "z": [65.0]}],
#                         {"height": 480, "legend": {"orientation": "h", "x": 0.03, "y": 1.3}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES FIJOS EN FORMA POLAR EN EL PLANO**
# La función tiene como sintaxis **plotpolarvectorsf2D** permite graficar multiples vectores fijos en el plano en forma polar.

# %%
import plotly.graph_objects as go
import numpy as np
import math


def plotpolarvectorsf2D(*args):

    '''Función elaborada con el módulo Plotly y NumPy  para representar multiples vectores fijos en el plano en forma polar'''
    
    fig = go.Figure()
    x = [0]
    y = [0]

    for v in args:

        r = v[0]
        theta_str = v[1]
        theta = math.radians(float(theta_str[:-1]))

        coor1 = round(r*math.cos(theta),3)
        coor2 = round(r*math.sin(theta),3)

        color = randomRgbaColor()
        x.append(coor1)
        y.append(coor2)
        #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
        fig.add_trace(go.Scatter(x=[0,coor1], y=[0,coor2],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(v)+1)))
        fig.add_annotation(
        x=coor1,  # Coordenada en x cabeza
        y=coor2,  # Coordenada en y cabeza
        ax=0.0,  # Coordenada en x de la cola
        ay=0.0,  # Coordenada en x de la cola
        xref='x',
        yref='y',
        axref='x',
        ayref='y',
        showarrow=True,
        arrowhead=2,
        arrowsize=1.5,
        arrowwidth=2.3,
        arrowcolor = color)
        
    fig.add_trace(go.Scatter(x=[0],y=[0],mode='markers',marker=dict(color="#2a3f5f",size=9),showlegend=True,opacity=1,name="origen"))

    fig.add_annotation(ax = min(x)-0.54, axref = 'x', ay = 0, ayref = 'y',x = max(x)+0.5, xref = 'x', y = 0, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(ax = 0, axref = 'x', ay = min(y) - 1, ayref = 'y',x = 0, xref = 'x', y = max(y)+0.5, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(text="$x$", x=max(x)+0.5, y=-0.2, arrowhead=1, showarrow=False)
    fig.add_annotation(text="$y$", x=-0.3, y=max(y)+0.5, arrowhead=1, showarrow=False)

    fig.update_xaxes(title = "$\large{x}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(x)-0.5, max(x)+0.5],showgrid = True) #,zerolinecolor="black" ,autorange = True
    fig.update_yaxes(title = "$\large{y}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(y)-0.5, max(y)+0.5],showgrid = True) #, zerolinecolor= "black" ,autorange = True
    fig.update_layout(font=dict(family="latex",size=20,color="black")) #y=1.2,x=0.03
    #fig.update_layout(title= "",title_font=dict(size=5, family='latex', color='rgb(1,21,51)'),title_x=0.5)
    fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="right",x=1, itemdoubleclick ="toggle"),title_font=dict(size=30, color='rgb(1,21,51)'),showlegend=True,width=500, height=480)
    fig.show()

# %%
plotpolarvectorsf2D([20,"30°"],[30,"60°"],[20,"90°"],[15,"120°"],[40,"280°"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="945ede61-3f2d-47ea-aae1-cdd3727f1961" class="plotly-graph-div" style="height:480px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("945ede61-3f2d-47ea-aae1-cdd3727f1961")) {
#                     Plotly.newPlot(
#                         '945ede61-3f2d-47ea-aae1-cdd3727f1961',
#                         [{"marker": {"color": "rgb(188,170,42)", "size": 8}, "mode": "lines", "name": "vector 1", "showlegend": true, "type": "scatter", "x": [0, 17.321], "y": [0, 10.0]}, {"marker": {"color": "rgb(156,29,165)", "size": 8}, "mode": "lines", "name": "vector 2", "showlegend": true, "type": "scatter", "x": [0, 15.0], "y": [0, 25.981]}, {"marker": {"color": "rgb(114,73,119)", "size": 8}, "mode": "lines", "name": "vector 3", "showlegend": true, "type": "scatter", "x": [0, 0.0], "y": [0, 20.0]}, {"marker": {"color": "rgb(105,218,37)", "size": 8}, "mode": "lines", "name": "vector 4", "showlegend": true, "type": "scatter", "x": [0, -7.5], "y": [0, 12.99]}, {"marker": {"color": "rgb(54,5,217)", "size": 8}, "mode": "lines", "name": "vector 5", "showlegend": true, "type": "scatter", "x": [0, 6.946], "y": [0, -39.392]}, {"marker": {"color": "#2a3f5f", "size": 9}, "mode": "markers", "name": "origen", "opacity": 1, "showlegend": true, "type": "scatter", "x": [0], "y": [0]}],
#                         {"annotations": [{"arrowcolor": "rgb(188,170,42)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 17.321, "xref": "x", "y": 10.0, "yref": "y"}, {"arrowcolor": "rgb(156,29,165)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 15.0, "xref": "x", "y": 25.981, "yref": "y"}, {"arrowcolor": "rgb(114,73,119)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 0.0, "xref": "x", "y": 20.0, "yref": "y"}, {"arrowcolor": "rgb(105,218,37)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": -7.5, "xref": "x", "y": 12.99, "yref": "y"}, {"arrowcolor": "rgb(54,5,217)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 6.946, "xref": "x", "y": -39.392, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": -8.04, "axref": "x", "ay": 0, "ayref": "y", "x": 17.821, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": 0, "axref": "x", "ay": -40.392, "ayref": "y", "x": 0, "xref": "x", "y": 26.481, "yref": "y"}, {"arrowhead": 1, "showarrow": false, "text": "$x$", "x": 17.821, "y": -0.2}, {"arrowhead": 1, "showarrow": false, "text": "$y$", "x": -0.3, "y": 26.481}], "font": {"color": "black", "family": "latex", "size": 20}, "height": 480, "legend": {"itemdoubleclick": "toggle", "orientation": "h", "x": 1, "xanchor": "right", "y": 1.02, "yanchor": "bottom"}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444 ...

# %% [markdown]
# ## **DEFINICIÓN DE LA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES EN FORMA POLAR EN EL PLANO**
# La función tiene como sintaxis **plotpolarvectorsl2D** permite graficar multiples vectores libres en el plano en forma polar.

# %%
import plotly.graph_objects as go
import numpy as np
import math


def plotpolarvectorsl2D(*args):

    '''Función elaborada con el módulo Plotly y NumPy  para representar multiples vectores libres en el plano en forma polar'''
    
    fig = go.Figure()
    x = [0]
    y = [0]

    for v in args:

        p_x = v[0][0]
        p_y = v[0][1]

        r = v[1][0]
        theta_str = v[1][1]
        theta = math.radians(float(theta_str[:-1]))

        coor1 = round(r*math.cos(theta),3)
        coor2 = round(r*math.sin(theta),3)

        color = randomRgbaColor()
        x.append(coor1 + p_x)
        x.append(p_x)
        y.append(coor2 + p_y)
        y.append(p_y)
        #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
        fig.add_trace(go.Scatter(x=[p_x,coor1+p_x], y=[p_y,coor2+p_y],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(v)+1)))
        fig.add_annotation(
        x=coor1 + p_x,  # Coordenada en x cabeza
        y=coor2 + p_y,  # Coordenada en y cabeza
        ax=p_x,  # Coordenada en x de la cola
        ay=p_y,  # Coordenada en x de la cola
        xref='x',
        yref='y',
        axref='x',
        ayref='y',
        showarrow=True,
        arrowhead=2,
        arrowsize=1.5,
        arrowwidth=2.3,
        arrowcolor = color)
        
    fig.add_trace(go.Scatter(x=[0],y=[0],mode='markers',marker=dict(color="#2a3f5f",size=9),showlegend=True,opacity=1,name="origen"))

    fig.add_annotation(ax = min(x)-0.54, axref = 'x', ay = 0, ayref = 'y',x = max(x)+0.5, xref = 'x', y = 0, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(ax = 0, axref = 'x', ay = min(y)-0.54, ayref = 'y',x = 0, xref = 'x', y = max(y)+0.5, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(text="$x$", x=max(x)+0.5, y=-0.2, arrowhead=1, showarrow=False)
    fig.add_annotation(text="$y$", x=-0.3, y=max(y)+0.5, arrowhead=1, showarrow=False)

    fig.update_xaxes(title = "$\large{x}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(x)-0.5, max(x)+0.5],showgrid = True) #,zerolinecolor="black" ,autorange = True
    fig.update_yaxes(title = "$\large{y}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(y)-0.5, max(y)+0.5],showgrid = True) #, zerolinecolor= "black" ,autorange = True
    fig.update_layout(font=dict(family="latex",size=20,color="black")) #y=1.2,x=0.03
    #fig.update_layout(title= "",title_font=dict(size=5, family='latex', color='rgb(1,21,51)'),title_x=0.5)
    fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="right",x=1, itemdoubleclick ="toggle"),title_font=dict(size=30, color='rgb(1,21,51)'),showlegend=True,width=500, height=480)
    fig.show()

# %%
plotpolarvectorsl2D([(1,2),(5,"-60°")],[(3.5,-2.33),(5,"90°")],[(3.5,2.67),(2,"140°")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ebad63a8-a933-44b6-94f8-f918cd892f49" class="plotly-graph-div" style="height:480px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ebad63a8-a933-44b6-94f8-f918cd892f49")) {
#                     Plotly.newPlot(
#                         'ebad63a8-a933-44b6-94f8-f918cd892f49',
#                         [{"marker": {"color": "rgb(24,132,76)", "size": 8}, "mode": "lines", "name": "vector 1", "showlegend": true, "type": "scatter", "x": [1, 3.5], "y": [2, -2.33]}, {"marker": {"color": "rgb(21,136,131)", "size": 8}, "mode": "lines", "name": "vector 2", "showlegend": true, "type": "scatter", "x": [3.5, 3.5], "y": [-2.33, 2.67]}, {"marker": {"color": "rgb(147,236,186)", "size": 8}, "mode": "lines", "name": "vector 3", "showlegend": true, "type": "scatter", "x": [3.5, 1.968], "y": [2.67, 3.956]}, {"marker": {"color": "#2a3f5f", "size": 9}, "mode": "markers", "name": "origen", "opacity": 1, "showlegend": true, "type": "scatter", "x": [0], "y": [0]}],
#                         {"annotations": [{"arrowcolor": "rgb(24,132,76)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 1, "axref": "x", "ay": 2, "ayref": "y", "showarrow": true, "x": 3.5, "xref": "x", "y": -2.33, "yref": "y"}, {"arrowcolor": "rgb(21,136,131)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 3.5, "axref": "x", "ay": -2.33, "ayref": "y", "showarrow": true, "x": 3.5, "xref": "x", "y": 2.67, "yref": "y"}, {"arrowcolor": "rgb(147,236,186)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 3.5, "axref": "x", "ay": 2.67, "ayref": "y", "showarrow": true, "x": 1.968, "xref": "x", "y": 3.956, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": -0.54, "axref": "x", "ay": 0, "ayref": "y", "x": 4.0, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": 0, "axref": "x", "ay": -2.87, "ayref": "y", "x": 0, "xref": "x", "y": 4.4559999999999995, "yref": "y"}, {"arrowhead": 1, "showarrow": false, "text": "$x$", "x": 4.0, "y": -0.2}, {"arrowhead": 1, "showarrow": false, "text": "$y$", "x": -0.3, "y": 4.4559999999999995}], "font": {"color": "black", "family": "latex", "size": 20}, "height": 480, "legend": {"itemdoubleclick": "toggle", "orientation": "h", "x": 1, "xanchor": "right", "y": 1.02, "yanchor": "bottom"}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e ...

# %% [markdown]
# ## **DEFINICIÓN DE LA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES Y FIJOS EN FORMA POLAR EN EL PLANO**
# La función tiene como sintaxis **plotpolarvectors2D** permite graficar multiples vectores libres en el plano en forma polar.

# %%
import plotly.graph_objects as go
import numpy as np
import math


def plotpolarvectors2D(*args):

    '''Función elaborada con el módulo Plotly y NumPy  para representar multiples vectores fijos y libres  en el plano en forma polar'''
    
    fig = go.Figure()
    x = [0]
    y = [0]
    for v in args:

        if type(v[0]) == int or type(v[0]) == float :
            r = v[0]
            theta_str = v[1]
            theta = math.radians(float(theta_str[:-1]))

            coor1 = round(r*math.cos(theta),3)
            coor2 = round(r*math.sin(theta),3)

            color = randomRgbaColor()
            x.append(coor1)
            y.append(coor2)
            #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
            fig.add_trace(go.Scatter(x=[0,coor1], y=[0,coor2],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(v)+1)))
            fig.add_annotation(
            x=coor1,  # Coordenada en x cabeza
            y=coor2,  # Coordenada en y cabeza
            ax=0.0,  # Coordenada en x de la cola
            ay=0.0,  # Coordenada en x de la cola
            xref='x',
            yref='y',
            axref='x',
            ayref='y',
            showarrow=True,
            arrowhead=2,
            arrowsize=1.5,
            arrowwidth=2.3,
            arrowcolor = color)

        else:

            p_x = v[0][0]
            p_y = v[0][1]

            r = v[1][0]
            theta_str = v[1][1]
            theta = math.radians(float(theta_str[:-1]))

            coor1 = round(r*math.cos(theta),3)
            coor2 = round(r*math.sin(theta),3)

            color = randomRgbaColor()
            x.append(coor1 + p_x)
            x.append(p_x)
            y.append(coor2 + p_y)
            y.append(p_y)
            #fig.add_trace(go.Scatter(x=[V[0]],y=[V[1]],mode='markers',marker=dict(color= color,size=7),showlegend=True,name="vector "+ str(args.index(V)+1)))
            fig.add_trace(go.Scatter(x=[p_x,coor1+p_x], y=[p_y,coor2+p_y],mode='lines',marker=dict(color= color,size=8),showlegend=True,name="vector "+ str(args.index(v)+1)))
            fig.add_annotation(
            x=coor1 + p_x,  # Coordenada en x cabeza
            y=coor2 + p_y,  # Coordenada en y cabeza
            ax=p_x,  # Coordenada en x de la cola
            ay=p_y,  # Coordenada en x de la cola
            xref='x',
            yref='y',
            axref='x',
            ayref='y',
            showarrow=True,
            arrowhead=2,
            arrowsize=1.5,
            arrowwidth=2.3,
            arrowcolor = color)
            
    fig.add_trace(go.Scatter(x=[0],y=[0],mode='markers',marker=dict(color="#2a3f5f",size=9),showlegend=True,opacity=1,name="origen"))

    fig.add_annotation(ax = min(x)-0.54, axref = 'x', ay = 0, ayref = 'y',x = max(x)+0.5, xref = 'x', y = 0, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(ax = 0, axref = 'x', ay = min(y)-0.54, ayref = 'y',x = 0, xref = 'x', y = max(y)+0.5, yref = 'y',arrowwidth = 1.5, arrowhead = 2,arrowcolor = "#2a3f5f")
    fig.add_annotation(text="$x$", x=max(x)+0.5, y=-0.2, arrowhead=1, showarrow=False)
    fig.add_annotation(text="$y$", x=-0.3, y=max(y)+0.5, arrowhead=1, showarrow=False)

    fig.update_xaxes(title = "$\large{x}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(x)-0.5, max(x)+0.5],showgrid = True) #,zerolinecolor="black" ,autorange = True
    fig.update_yaxes(title = "$\large{y}$", title_font=dict(size=30, family='latex', color='rgb(1,21,51)'),range = [min(y)-0.5, max(y)+0.5],showgrid = True) #, zerolinecolor= "black" ,autorange = True
    fig.update_layout(font=dict(family="latex",size=20,color="black")) #y=1.2,x=0.03
    #fig.update_layout(title= "",title_font=dict(size=5, family='latex', color='rgb(1,21,51)'),title_x=0.5)
    fig.update_layout(legend=dict(orientation="h",yanchor="bottom",y=1.02,xanchor="right",x=1, itemdoubleclick ="toggle"),title_font=dict(size=30, color='rgb(1,21,51)'),showlegend=True,width=500, height=480)
    fig.show()

# %%
plotpolarvectors2D([4,"30°"],[(3.464,2),(5,"120°")],[(0.964,6.33),(4,"265°")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="22065a74-19e9-4231-8e56-b56776c907e0" class="plotly-graph-div" style="height:480px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("22065a74-19e9-4231-8e56-b56776c907e0")) {
#                     Plotly.newPlot(
#                         '22065a74-19e9-4231-8e56-b56776c907e0',
#                         [{"marker": {"color": "rgb(161,64,38)", "size": 8}, "mode": "lines", "name": "vector 1", "showlegend": true, "type": "scatter", "x": [0, 3.464], "y": [0, 2.0]}, {"marker": {"color": "rgb(13,44,97)", "size": 8}, "mode": "lines", "name": "vector 2", "showlegend": true, "type": "scatter", "x": [3.464, 0.964], "y": [2, 6.33]}, {"marker": {"color": "rgb(44,180,115)", "size": 8}, "mode": "lines", "name": "vector 3", "showlegend": true, "type": "scatter", "x": [0.964, 0.615], "y": [6.33, 2.345]}, {"marker": {"color": "#2a3f5f", "size": 9}, "mode": "markers", "name": "origen", "opacity": 1, "showlegend": true, "type": "scatter", "x": [0], "y": [0]}],
#                         {"annotations": [{"arrowcolor": "rgb(161,64,38)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.0, "axref": "x", "ay": 0.0, "ayref": "y", "showarrow": true, "x": 3.464, "xref": "x", "y": 2.0, "yref": "y"}, {"arrowcolor": "rgb(13,44,97)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 3.464, "axref": "x", "ay": 2, "ayref": "y", "showarrow": true, "x": 0.964, "xref": "x", "y": 6.33, "yref": "y"}, {"arrowcolor": "rgb(44,180,115)", "arrowhead": 2, "arrowsize": 1.5, "arrowwidth": 2.3, "ax": 0.964, "axref": "x", "ay": 6.33, "ayref": "y", "showarrow": true, "x": 0.615, "xref": "x", "y": 2.345, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": -0.54, "axref": "x", "ay": 0, "ayref": "y", "x": 3.964, "xref": "x", "y": 0, "yref": "y"}, {"arrowcolor": "#2a3f5f", "arrowhead": 2, "arrowwidth": 1.5, "ax": 0, "axref": "x", "ay": -0.54, "ayref": "y", "x": 0, "xref": "x", "y": 6.83, "yref": "y"}, {"arrowhead": 1, "showarrow": false, "text": "$x$", "x": 3.964, "y": -0.2}, {"arrowhead": 1, "showarrow": false, "text": "$y$", "x": -0.3, "y": 6.83}], "font": {"color": "black", "family": "latex", "size": 20}, "height": 480, "legend": {"itemdoubleclick": "toggle", "orientation": "h", "x": 1, "xanchor": "right", "y": 1.02, "yanchor": "bottom"}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.44444444444444 ...

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES FIJOS EN EL ESPACIO EN TÉRMINOS DE SU MAGNITUD Y UN VECTOR DIRECCIÓN UNITARIO**
# La función tiene como sintaxis **plotdirectvectorsf3D** permite realizar la representación gráfica de multiples vectores fijos en el espacio segun su magnitud y vector dirección unitario.

# %%
import plotly.graph_objs as go
from plotly.offline import plot
import numpy as np
i = (1,0,0)
j = (0,1,0)
k = (0,0,1)

mi = (-1,0,0)
mj = (0,-1,0)
mk = (0,0,-1)

def plotdirectvectorsf3D(*args):

    ''''Función elaborada con el módulo Plotly y NumPy para representar gráficamente multiples vectores fijos en el espacio dada su magnitud y
       vector dirección unitario'''

    data = []
    x = [0]
    y = [0]
    z = [0.3,-0.3]

    for v in args:

        magni = v[0]

        dir_x = v[1][0]
        dir_y = v[1][1]
        dir_z = v[1][2]

        V = [magni *v[1][0],magni*v[1][1],magni*v[1][2]]

        x.append(V[0])
        y.append(V[1])
        z.append(V[2])

    escala =(max(x)+max(y)+max(z))/20

    
    for v in args:

        magni = v[0]

        dir_x = v[1][0]
        dir_y = v[1][1]
        dir_z = v[1][2]

        V = [magni *v[1][0],magni*v[1][1],magni*v[1][2]]

        #x.append(V[0])
        #y.append(V[1])
        #z.append(V[2])
        color = randomRgbaColor()
        vector = go.Scatter3d( 
        x = [0,V[0]],
        y = [0,V[1]],
        z = [0,V[2]],
        marker = dict( size = 1,color= color),
        line = dict( color= color, width = 7),name="vector "+ str(args.index(v)+1))
        
        paleta = [[0, color],[1, color]]

        cono = go.Cone(x=[V[0]], y=[V[1]], z=[V[2]], u=[V[0]], v=[V[1]], w=[V[2]],sizemode="absolute",sizeref= escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(v)+1))
        
        data += [vector,cono]
        layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

    paleta2 = [[0, "#2a3f5f"],[1, "#2a3f5f"]]
    point = go.Scatter3d( x = [0],y = [0],z = [0], mode='markers',marker=dict(color= "#2a3f5f",size=5),showlegend=True,name="origen")
    
    axex = go.Scatter3d( 
        x = [min(x)- escala, max(x)+escala],
        y = [0,0],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    
    conox = go.Cone(x=[max(x)+escala], y=[0], z=[0], u=[max(x)+escala], v=[0], w=[0],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),name="Eje x-positivo")
    
    axey = go.Scatter3d( 
        x = [0,0],
        y = [min(y)-escala,max(y)+escala],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color="#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    conoy = go.Cone(x=[0], y=[max(y)+escala], z=[0], u=[0], v=[max(y)+escala], w=[0],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje y-positivo ")
    
    axez = go.Scatter3d( 
        x = [0,0],
        y = [0,0],
        z = [min(z)-escala,max(z)+escala],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="eje z-positivo")
    
    conoz = go.Cone(x=[0], y=[0], z=[max(z)+escala], u=[0], v=[0], w=[max(z)+escala],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo= "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje z-positivo")
    
    
    #plano = go.Surface(x = np.linspace(min(x),max(x),500), y = np.linspace(min(y),max(y),500) ,z = np.zeros(500),showscale=False)

    fig = go.Figure(data= data + [point, axex, conox, axey, conoy, axez, conoz] ,layout=layout)


    fig.update_layout(legend=dict(orientation="h",y=1.3,x=0.03),title_font=dict(size=50, color='rgb(1,21,51)'),showlegend=True,width=480, height=480)


    plot(fig,image_height=800,image_width=800)
    fig.show()

# %%
plotdirectvectorsf3D([3,i],[4,j],[5,k],[2,(1,1,1)])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ae8d1aa4-b233-4538-b9a4-e3e13a256c84" class="plotly-graph-div" style="height:480px; width:480px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ae8d1aa4-b233-4538-b9a4-e3e13a256c84")) {
#                     Plotly.newPlot(
#                         'ae8d1aa4-b233-4538-b9a4-e3e13a256c84',
#                         [{"line": {"color": "rgb(236,86,41)", "width": 7}, "marker": {"color": "rgb(236,86,41)", "size": 1}, "name": "vector 1", "type": "scatter3d", "x": [0, 3], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(236,86,41)"], [1, "rgb(236,86,41)"]], "name": "vector 1", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [3], "v": [0], "w": [0], "x": [3], "y": [0], "z": [0]}, {"line": {"color": "rgb(155,121,231)", "width": 7}, "marker": {"color": "rgb(155,121,231)", "size": 1}, "name": "vector 2", "type": "scatter3d", "x": [0, 0], "y": [0, 4], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(155,121,231)"], [1, "rgb(155,121,231)"]], "name": "vector 2", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [0], "v": [4], "w": [0], "x": [0], "y": [4], "z": [0]}, {"line": {"color": "rgb(82,105,200)", "width": 7}, "marker": {"color": "rgb(82,105,200)", "size": 1}, "name": "vector 3", "type": "scatter3d", "x": [0, 0], "y": [0, 0], "z": [0, 5]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(82,105,200)"], [1, "rgb(82,105,200)"]], "name": "vector 3", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [0], "v": [0], "w": [5], "x": [0], "y": [0], "z": [5]}, {"line": {"color": "rgb(121,146,218)", "width": 7}, "marker": {"color": "rgb(121,146,218)", "size": 1}, "name": "vector 4", "type": "scatter3d", "x": [0, 2], "y": [0, 2], "z": [0, 2]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(121,146,218)"], [1, "rgb(121,146,218)"]], "name": "vector 4", "showscale": false, "sizemode": "absolute", "sizeref": 0.6, "type": "cone", "u": [2], "v": [2], "w": [2], "x": [2], "y": [2], "z": [2]}, {"marker": {"color": "#2a3f5f", "size": 5}, "mode": "markers", "name": "origen", "showlegend": true, "type": "scatter3d", "x": [0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [-0.6, 3.6], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje x-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.3, "type": "cone", "u": [3.6], "v": [0], "w": [0], "x": [3.6], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [-0.6, 4.6], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje y-positivo ", "showscale": false, "sizemode": "absolute", "sizeref": 0.3, "type": "cone", "u": [0], "v": [4.6], "w": [0], "x": [0], "y": [4.6], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "eje z-positivo", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [0, 0], "z": [-0.8999999999999999, 5.6]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje z-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.3, "type": "cone", "u": [0], "v": [0], "w": [5.6], "x": [0], "y": [0], "z": [5.6]}],
#                         {"height": 480, "legend": {"orientation": "h", "x": 0.03, "y": 1.3}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "sca

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES LIBRES EN EL ESPACIO EN TÉRMINOS DE SU MAGNITUD Y UN VECTOR DIRECCIÓN UNITARIO**
# La función tiene como sintaxis **plotdirectvectorsl3D** permite realizar la representación gráfica de multiples vectores fijos en el espacio segun su magnitud y vector dirección unitario.

# %%
import plotly.graph_objs as go
from plotly.offline import plot
import numpy as np


i = (1,0,0)
j = (0,1,0)
k = (0,0,1)

mi = (-1,0,0)
mj = (0,-1,0)
mk = (0,0,-1)



def plotdirectvectorsl3D(*args):
    '''Función elaborada en el módulo Plotly y NumPy para representar graficamente multiples vectores libres en el espacio en terminos 
    de la magnitud y un vector dirección unitario'''

    data = []
    x = [0]
    y = [0]
    z = [0.3,-0.3]

    for v in args:
        
        p_x = v[0][0]
        p_y = v[0][1]
        p_z = v[0][2]


        magni = v[1]

        dir_x = v[2][0]
        dir_y = v[2][1]
        dir_z = v[2][2]

        V = [magni *dir_x+p_x ,magni*dir_y+p_y,magni*dir_z+p_z]

        x.append(p_x)
        y.append(p_y)
        z.append(p_z)


        x.append(V[0])
        y.append(V[1])
        z.append(V[2])

    escala =(max(x)+max(y)+max(z))/20



    for v in args:

        p_x = v[0][0]
        p_y = v[0][1]
        p_z = v[0][2]


        magni = v[1]

        dir_x = v[2][0]
        dir_y = v[2][1]
        dir_z = v[2][2]

        V = [magni *dir_x+p_x ,magni*dir_y+p_y,magni*dir_z+p_z]

        x.append(p_x)
        y.append(p_y)
        z.append(p_z)


        x.append(V[0])
        y.append(V[1])
        z.append(V[2])

        nombre = "Tail"+ "=" + "(" + str(v[0][0])  + "," + str(v[0][1]) +"," +str(v[0][2]) + ")" + "\n" + "Head"+ "=" + "(" + str(V[0])  + "," + str(V[1]) +"," +str(V[2]) + ")"

        color = randomRgbaColor()
        vector = go.Scatter3d( 
        x = [p_x,V[0]],
        y = [p_y,V[1]],
        z = [p_z,V[2]],
        hoverinfo = "name + text",
        hovertext = nombre,
        marker = dict( size = 1,color= color),
        line = dict( color= color, width = 7),name="vector "+ str(args.index(v)+1))
        
        paleta = [[0, color],[1, color]]

        cono = go.Cone(x=[V[0]-0.063*(V[0]-p_x)], y=[V[1]-0.063*(V[1]-p_y)], z=[V[2]-0.063*(V[2]-p_z)], u=[0.5*(V[0]-p_x)], v=[0.5*(V[1]-p_y)], w=[0.5*(V[2]-p_z)],sizemode="absolute",sizeref=escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               hoverinfo = "skip",
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(v)+1))
        
        data += [vector,cono]
        layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

    paleta2 = [[0, "#2a3f5f"],[1, "#2a3f5f"]]
    point = go.Scatter3d( x = [0],y = [0],z = [0], mode='markers',marker=dict(color= "#2a3f5f",size=5),showlegend=True,name="origen")
    
    axex = go.Scatter3d( 
        x = [min(x)-escala, max(x)+escala],
        y = [0,0],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    
    conox = go.Cone(x=[max(x)+escala], y=[0], z=[0], u=[max(x)+escala], v=[0], w=[0],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),name="Eje x-positivo")
    
    axey = go.Scatter3d( 
        x = [0,0],
        y = [min(y)-escala,max(y)+escala],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color="#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    conoy = go.Cone(x=[0], y=[max(y)+escala], z=[0], u=[0], v=[max(y)+escala], w=[0],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje y-positivo ")
    
    axez = go.Scatter3d( 
        x = [0,0],
        y = [0,0],
        z = [min(z)-escala,max(z)+escala],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="eje z-positivo")
    
    conoz = go.Cone(x=[0], y=[0], z=[max(z)+escala], u=[0], v=[0], w=[max(z)+escala],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo= "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje z-positivo")
    
    
    #plano = go.Surface(x = np.linspace(min(x),max(x),500), y = np.linspace(min(y),max(y),500) ,z = np.zeros(500),showscale=False)

    fig = go.Figure(data= data + [point, axex, conox, axey, conoy, axez, conoz] ,layout=layout)


    fig.update_layout(legend=dict(orientation="h",y=1.3,x=0.03),title_font=dict(size=50, color='rgb(1,21,51)'),showlegend=True,width=480, height=480)


    plot(fig,image_height=800,image_width=800)
    fig.show()

# %%
plotdirectvectorsl3D([(1,2,3),2,i],[(1,2,3),5,j],[(1,2,3),2,k],[(1,2,3),3,(1,1,1)],[(1,2,3),4,mi])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f7834795-cc19-4358-bf6f-88e556929584" class="plotly-graph-div" style="height:480px; width:480px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7834795-cc19-4358-bf6f-88e556929584")) {
#                     Plotly.newPlot(
#                         'f7834795-cc19-4358-bf6f-88e556929584',
#                         [{"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(3,2,3)", "line": {"color": "rgb(17,44,198)", "width": 7}, "marker": {"color": "rgb(17,44,198)", "size": 1}, "name": "vector 1", "type": "scatter3d", "x": [1, 3], "y": [2, 2], "z": [3, 3]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(17,44,198)"], [1, "rgb(17,44,198)"]], "hoverinfo": "skip", "name": "vector 1", "showscale": false, "sizemode": "absolute", "sizeref": 0.85, "type": "cone", "u": [1.0], "v": [0.0], "w": [0.0], "x": [2.874], "y": [2.0], "z": [3.0]}, {"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(1,7,3)", "line": {"color": "rgb(39,175,253)", "width": 7}, "marker": {"color": "rgb(39,175,253)", "size": 1}, "name": "vector 2", "type": "scatter3d", "x": [1, 1], "y": [2, 7], "z": [3, 3]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(39,175,253)"], [1, "rgb(39,175,253)"]], "hoverinfo": "skip", "name": "vector 2", "showscale": false, "sizemode": "absolute", "sizeref": 0.85, "type": "cone", "u": [0.0], "v": [2.5], "w": [0.0], "x": [1.0], "y": [6.685], "z": [3.0]}, {"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(1,2,5)", "line": {"color": "rgb(70,57,96)", "width": 7}, "marker": {"color": "rgb(70,57,96)", "size": 1}, "name": "vector 3", "type": "scatter3d", "x": [1, 1], "y": [2, 2], "z": [3, 5]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(70,57,96)"], [1, "rgb(70,57,96)"]], "hoverinfo": "skip", "name": "vector 3", "showscale": false, "sizemode": "absolute", "sizeref": 0.85, "type": "cone", "u": [0.0], "v": [0.0], "w": [1.0], "x": [1.0], "y": [2.0], "z": [4.874]}, {"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(4,5,6)", "line": {"color": "rgb(126,242,135)", "width": 7}, "marker": {"color": "rgb(126,242,135)", "size": 1}, "name": "vector 4", "type": "scatter3d", "x": [1, 4], "y": [2, 5], "z": [3, 6]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(126,242,135)"], [1, "rgb(126,242,135)"]], "hoverinfo": "skip", "name": "vector 4", "showscale": false, "sizemode": "absolute", "sizeref": 0.85, "type": "cone", "u": [1.5], "v": [1.5], "w": [1.5], "x": [3.811], "y": [4.811], "z": [5.811]}, {"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(-3,2,3)", "line": {"color": "rgb(88,113,99)", "width": 7}, "marker": {"color": "rgb(88,113,99)", "size": 1}, "name": "vector 5", "type": "scatter3d", "x": [1, -3], "y": [2, 2], "z": [3, 3]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(88,113,99)"], [1, "rgb(88,113,99)"]], "hoverinfo": "skip", "name": "vector 5", "showscale": false, "sizemode": "absolute", "sizeref": 0.85, "type": "cone", "u": [-2.0], "v": [0.0], "w": [0.0], "x": [-2.748], "y": [2.0], "z": [3.0]}, {"marker": {"color": "#2a3f5f", "size": 5}, "mode": "markers", "name": "origen", "showlegend": true, "type": "scatter3d", "x": [0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [-3.85, 4.85], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje x-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.425, "type": "cone", "u": [4.85], "v": [0], "w": [0], "x": [4.85], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [-0.85, 7.85], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje y-positivo ", "showscale": false, "sizemode": "absolute", "sizeref": 0.425, "type": "cone", "u": [0], "v": [7 ...
#                         {"height": 480, "legend": {"orientation": "h", "x": 0.03, "y": 1.3}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.77777

# %%
_i = (-1,0,0)
_i
# Out:
# (-1, 0, 0)

# %% [markdown]
# ## **DEFINICIÓN DE UNA FUNCIÓN PARA GRAFICAR MULTIPLES VECTORES FIJOS O LIBRES EN EL ESPACIO EN TÉRMINOS DE SU MAGNITUD Y UN VECTOR DIRECCIÓN UNITARIO**
# La función tiene como sintaxis **plotdirectvectors3D** permite realizar la representación gráfica de multiples vectores fijos en el espacio segun su magnitud y vector dirección unitario.

# %%
import plotly.graph_objs as go
from plotly.offline import plot
import numpy as np


i = (1,0,0)
j = (0,1,0)
k = (0,0,1)

mi = (-1,0,0)
mj = (0,-1,0)
mk = (0,0,-1)



def plotdirectvectors3D(*args):
    '''Función elaborada en el módulo Plotly y NumPy para representar graficamente multiples vectores libres en el espacio en terminos 
    de la magnitud y un vector dirección unitario'''

    data = []
    x = [0]
    y = [0]
    z = [0.3,-0.3]

    for v in args:

        if type(v[0]) == int or type(v[0]) == float :

             magni = v[0]
             dir_x = v[1][0]
             dir_y = v[1][1]
             dir_z = v[1][2]
             V = [magni *v[1][0],magni*v[1][1],magni*v[1][2]]
             
             x.append(V[0])
             y.append(V[1])
             z.append(V[2])
        else:
            p_x = v[0][0]
            p_y = v[0][1]
            p_z = v[0][2]


            magni = v[1]

            dir_x = v[2][0]
            dir_y = v[2][1]
            dir_z = v[2][2]

            V = [magni *dir_x+p_x ,magni*dir_y+p_y,magni*dir_z+p_z]

            x.append(p_x)
            y.append(p_y)
            z.append(p_z)


            x.append(V[0])
            y.append(V[1])
            z.append(V[2])

    escala =(max(x)+max(y)+max(z))/20

    for v in args:
        if type(v[0]) == int or type(v[0]) == float :

            magni = v[0]

            dir_x = v[1][0]
            dir_y = v[1][1]
            dir_z = v[1][2]

            V = [magni *v[1][0],magni*v[1][1],magni*v[1][2]]

            #x.append(V[0])
            #y.append(V[1])
            #z.append(V[2])
            color = randomRgbaColor()
            vector = go.Scatter3d( 
            x = [0,V[0]],
            y = [0,V[1]],
            z = [0,V[2]],
            marker = dict( size = 1,color= color),
            line = dict( color= color, width = 7),name="vector "+ str(args.index(v)+1))
        
            paleta = [[0, color],[1, color]]

            cono = go.Cone(x=[V[0]], y=[V[1]], z=[V[2]], u=[V[0]], v=[V[1]], w=[V[2]],sizemode="absolute",sizeref= escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(v)+1))
        
            data += [vector,cono]
            layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

        else:

            p_x = v[0][0]
            p_y = v[0][1]
            p_z = v[0][2]


            magni = v[1]

            dir_x = v[2][0]
            dir_y = v[2][1]
            dir_z = v[2][2]

            V = [magni *dir_x+p_x ,magni*dir_y+p_y,magni*dir_z+p_z]

            x.append(p_x)
            y.append(p_y)
            z.append(p_z)


            x.append(V[0])
            y.append(V[1])
            z.append(V[2])

            nombre = "Tail"+ "=" + "(" + str(v[0][0])  + "," + str(v[0][1]) +"," +str(v[0][2]) + ")" + "\n" + "Head"+ "=" + "(" + str(V[0])  + "," + str(V[1]) +"," +str(V[2]) + ")"

            color = randomRgbaColor()
            vector = go.Scatter3d( 
            x = [p_x,V[0]],
            y = [p_y,V[1]],
            z = [p_z,V[2]],
            hoverinfo = "name + text",
            hovertext = nombre,
            marker = dict( size = 1,color= color),
            line = dict( color= color, width = 7),name="vector "+ str(args.index(v)+1))
        
            paleta = [[0, color],[1, color]]

            cono = go.Cone(x=[V[0]-0.063*(V[0]-p_x)], y=[V[1]-0.063*(V[1]-p_y)], z=[V[2]-0.063*(V[2]-p_z)], u=[0.5*(V[0]-p_x)], v=[0.5*(V[1]-p_y)], w=[0.5*(V[2]-p_z)],sizemode="absolute",sizeref=escala,anchor="cm",
               showscale=False,
               colorscale=paleta,
               hoverinfo = "skip",
               colorbar=dict(thickness=20, ticklen=4),
               name="vector "+ str(args.index(v)+1))
        
            data += [vector,cono]
            layout = go.Layout(margin = dict( l = 0,r = 0,b = 0,t = 0))

    paleta2 = [[0, "#2a3f5f"],[1, "#2a3f5f"]]
    point = go.Scatter3d( x = [0],y = [0],z = [0], mode='markers',marker=dict(color= "#2a3f5f",size=5),showlegend=True,name="origen")
    
    axex = go.Scatter3d( 
        x = [min(x)-escala, max(x)+escala],
        y = [0,0],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    
    conox = go.Cone(x=[max(x)+escala], y=[0], z=[0], u=[max(x)+escala], v=[0], w=[0],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),name="Eje x-positivo")
    
    axey = go.Scatter3d( 
        x = [0,0],
        y = [min(y)-escala,max(y)+escala],
        z = [0,0],
        hoverinfo = "skip",
        marker = dict( size = 1,color="#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="")
    
    conoy = go.Cone(x=[0], y=[max(y)+escala], z=[0], u=[0], v=[max(y)+escala], w=[0],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo = "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje y-positivo ")
    
    axez = go.Scatter3d( 
        x = [0,0],
        y = [0,0],
        z = [min(z)-escala,max(z)+escala],
        hoverinfo = "skip",
        marker = dict( size = 1,color= "#2a3f5f"),
        line = dict( color= "#2a3f5f", width = 3), showlegend=False,name="eje z-positivo")
    
    conoz = go.Cone(x=[0], y=[0], z=[max(z)+escala], u=[0], v=[0], w=[max(z)+escala],sizemode="absolute",sizeref=escala*0.5,anchor="cm",
               showscale=False,
               colorscale=paleta2,
               hoverinfo= "name",
               colorbar=dict(thickness=20, ticklen=4),
               name="Eje z-positivo")
    
    
    #plano = go.Surface(x = np.linspace(min(x),max(x),500), y = np.linspace(min(y),max(y),500) ,z = np.zeros(500),showscale=False)

    fig = go.Figure(data= data + [point, axex, conox, axey, conoy, axez, conoz] ,layout=layout)


    fig.update_layout(legend=dict(orientation="h",y=1.3,x=0.03),title_font=dict(size=50, color='rgb(1,21,51)'),showlegend=True,width=480, height=480)


    plot(fig,image_height=800,image_width=800)
    fig.show()

# %%
plotdirectvectors3D([(1,2,3),2,i],[2,(1/5,2/5,3/5)],[3,(1,1,1)])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be9ffb45-2434-4393-92e0-e20a8d9cd63d" class="plotly-graph-div" style="height:480px; width:480px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be9ffb45-2434-4393-92e0-e20a8d9cd63d")) {
#                     Plotly.newPlot(
#                         'be9ffb45-2434-4393-92e0-e20a8d9cd63d',
#                         [{"hoverinfo": "name+text", "hovertext": "Tail=(1,2,3)\nHead=(3,2,3)", "line": {"color": "rgb(206,60,53)", "width": 7}, "marker": {"color": "rgb(206,60,53)", "size": 1}, "name": "vector 1", "type": "scatter3d", "x": [1, 3], "y": [2, 2], "z": [3, 3]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(206,60,53)"], [1, "rgb(206,60,53)"]], "hoverinfo": "skip", "name": "vector 1", "showscale": false, "sizemode": "absolute", "sizeref": 0.45, "type": "cone", "u": [1.0], "v": [0.0], "w": [0.0], "x": [2.874], "y": [2.0], "z": [3.0]}, {"line": {"color": "rgb(47,51,204)", "width": 7}, "marker": {"color": "rgb(47,51,204)", "size": 1}, "name": "vector 2", "type": "scatter3d", "x": [0, 0.4], "y": [0, 0.8], "z": [0, 1.2]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(47,51,204)"], [1, "rgb(47,51,204)"]], "name": "vector 2", "showscale": false, "sizemode": "absolute", "sizeref": 0.45, "type": "cone", "u": [0.4], "v": [0.8], "w": [1.2], "x": [0.4], "y": [0.8], "z": [1.2]}, {"line": {"color": "rgb(157,138,189)", "width": 7}, "marker": {"color": "rgb(157,138,189)", "size": 1}, "name": "vector 3", "type": "scatter3d", "x": [0, 3], "y": [0, 3], "z": [0, 3]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "rgb(157,138,189)"], [1, "rgb(157,138,189)"]], "name": "vector 3", "showscale": false, "sizemode": "absolute", "sizeref": 0.45, "type": "cone", "u": [3], "v": [3], "w": [3], "x": [3], "y": [3], "z": [3]}, {"marker": {"color": "#2a3f5f", "size": 5}, "mode": "markers", "name": "origen", "showlegend": true, "type": "scatter3d", "x": [0], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [-0.45, 3.45], "y": [0, 0], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje x-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.225, "type": "cone", "u": [3.45], "v": [0], "w": [0], "x": [3.45], "y": [0], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [-0.45, 3.45], "z": [0, 0]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje y-positivo ", "showscale": false, "sizemode": "absolute", "sizeref": 0.225, "type": "cone", "u": [0], "v": [3.45], "w": [0], "x": [0], "y": [3.45], "z": [0]}, {"hoverinfo": "skip", "line": {"color": "#2a3f5f", "width": 3}, "marker": {"color": "#2a3f5f", "size": 1}, "name": "eje z-positivo", "showlegend": false, "type": "scatter3d", "x": [0, 0], "y": [0, 0], "z": [-0.75, 3.45]}, {"anchor": "cm", "colorbar": {"thickness": 20, "ticklen": 4}, "colorscale": [[0, "#2a3f5f"], [1, "#2a3f5f"]], "hoverinfo": "name", "name": "Eje z-positivo", "showscale": false, "sizemode": "absolute", "sizeref": 0.225, "type": "cone", "u": [0], "v": [0], "w": [3.45], "x": [0], "y": [0], "z": [3.45]}],
#                         {"height": 480, "legend": {"orientation": "h", "x": 0.03, "y": 1.3}, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinew
